# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %%
# %run _Thinkific_Driver.ipynb

# %% [markdown]
# # Thinkific - Get courses

# %%
from naas_drivers import *

# Run notebook to get credentials
# %run _Thinkific_Credentials.ipynb

# Connect to thinkific
tk = thinkific.connect(auth_token, subdomain)

# %%
# Get all courses
df_courses = tk.courses.get_all()
df_courses
# Out:
#          id                                               name  \
# 0    944867                             Excel en mode efficace
# 1    944913    Structurez votre Excel pour parler aux machines
# 2    944980      Créez un tableau de bord automatisé sur Excel
# 3    944988                          On aime tous Excel, mais…
# 4    945012                           N’ayez pas peur du code!
# 5    945059              Netflix et la puissance des Notebooks
# 6    945091              Créez votre premier script (partie 1)
# 7    945097  Allez plus loin (graphiques, connecteurs et ma...
# 8    946348  Programmez vos tâches (travaillez même en dorm...
# 9    946356                Actualisez simplement votre travail
# 10   946358         Diffusez vos rapports au plus grand nombre
# 11   946360                                 Passez à l’échelle
# 12   986495              Créez votre premier script (partie 2)
# 13  1000964                          Python : Pour approfondir
#
#                                                 slug subtitle  product_id  \
# 0                          excel-mode-super-efficace     None      992770
# 1                             structurer-votre-excel     None      992817
# 2                creer-un-tableau-de-bord-automatise     None      992886
# 3                            on-aime-tous-excel-mais     None      992895
# 4                          n-ayez-pas-peur-du-python     None      992923
# 5                           netflix-et-les-notebooks     None      992971
# 6                creez-votre-premier-script-partie-1     None      993004
# 7                                    aller-plus-loin     None      993010
# 8   programmez-vos-taches-travaillez-meme-en-dormant     None      994333
# 9                actualisez-simplement-votre-travail     None      994341
# 10        diffusez-vos-rapports-au-plus-grand-nombre     None      994343
# 11                                passez-a-l-echelle     None      994345
# 12               creez-votre-premier-script-partie-2     None     1036478
# 13                           python-pour-approfondir     None     1051673
#
#                                           description intro_video_youtube  \
# 0   Excel… On connait tous, mais comment l’utilise...                None
# 1   Comment extraire, enrichir et manipuler des do...                None
# 2   Les bonnes pratiques de data-visualisation et ...                None
# 3                                                None                None
# 4   Quand on sait que Python est le langage inform...                None
# 5   Découvrez le pouvoir du scripting depuis votre...                None
# 6                                                None                None
# 7                                       Coming soon.😉                None
# 8                                                None                None
# 9                                                None                None
# 10                                               None                None
# 11                                               None                None
# 12                                               None                None
# 13                                               None                None
#
#    contact_information keywords duration  \
# 0                 None     None     None
# 1                 None     None     None
# 2                 None     None     None
# 3                 None     None     None
# 4                 None     None     None
# 5                 None     None     None
# 6                 None     None     None
# 7                 None     None     None
# 8                 None     None     None
# 9                 None     None     None
# 10                None     None     None
# 11                None     None     None
# 12                None     None     None
# 13                None     None     None
#
#                             banner_image_url  \
# 0   /assets/tenant/default-course-banner.jpg
# 1   /assets/tenant/default-course-banner.jpg
# 2   /assets/tenant/default-course-banner.jpg
# 3   /assets/tenant/default-course-banner.jpg
# 4   /assets/tenant/default-course-banner.jpg
# 5   /assets/tenant/default-course-banner.jpg
# 6   /assets/tenant/default-course-banner.jpg
# 7   /assets/tenant/default-course-banner.jpg
# 8   /assets/tenant/default-course-banner.jpg
# 9   /assets/tenant/default-course-banner.jpg
# 10  /assets/tenant/default-course-banner.jpg
# 11  /assets/tenant/default-course-banner.jpg
# 12  /assets/tenant/default-course-banner.jpg
# 13  /assets/tenant/default-course-banner.jpg
#
#                                 course_card_image_url  \
# 0   https://thinkific-import.s3.amazonaws.com/3701...
# 1   https://thinkific-import.s3.amazonaws.com/3701...
# 2   https://thinkific-import.s3.amazonaws.com/3701...
# 3   https://thinkific-import.s3.amazonaws.com/3701...
# 4   https://thinkific-import.s3.amazonaws.com/3701...
# 5   https://thinkific-import.s3.amazonaws.com/3701...
# 6   https://thinkific-import.s3.amazonaws.com/3701...
# 7   https://thinkific-import.s3.amazonaws.com/3701...
# 8   https://thinkific-import.s3.amazonaws.com/3701...
# 9   https://thinkific-import.s3.amazonaws.com/3701...
# 10  https://thinkific-import.s3.amazonaws.com/3701...
# 11  https://thinkific-import.s3.amazonaws.com/3701...
# 12  https://s3.amazonaws.com/thinkific/courses/cou...
# 13  https://thinkific-import.s3.amazonaws.com/3701...
#
#    intro_video_wistia_identifier administrator_user_ids     user_id  \
# 0                           None                     []  30297688.0
# 1                           None                     []         NaN
# 2                           None                     []  30297688.0
# 3                           None                     []  30297688.0
# 4                           None                     []  30297688.0
# 5                           None                     []  30297688.0
# 6                           None                     []  30297688.0
# 7                           None                     []  30297688.0
# 8                           None                     []  30297688.0
# 9                           None                     []  30297688.0
# 10                          None                     []  30297688.0
# 11                          None                     []  30297688.0
# 12                          None                     []         NaN
# 13                          None                     []  30297688.0
#
#     reviews_enabled  instructor_id  \
# 0             False         429558
# 1             False         429558
# 2             False         429558
# 3             False         429558
# 4             False         429558
# 5             False         429558
# 6             False         429558
# 7             False         429558
# 8             False         429558
# 9             False         429558
# 10            False         429558
# 11            False         429558
# 12            False         429558
# 13            False         429558
#
#                                           chapter_ids course_card_text
# 0                [4231577, 4231584, 4231590, 4231600]             None
# 1       [4231746, 4231747, 4231748, 4231749, 4231750]             None
# 2       [4232139, 4232141, 4232142, 4232143, 4293663]             None
# 3                                           [4554793]             None
# 4                                           [4232266]             None
# 5                                           [4232448]             None
# 6                [4232568, 4416059, 4232571, 4232573]             None
# 7                         [4232592, 4232593, 4245444]             None
# 8                                           [4238084]             None
# 9                                           [4245458]             None
# 10                                          [4245478]             None
# 11                                          [4238333]             None
# 12                        [4422434, 4422435, 4422436]             None
# 13  [4563930, 4482837, 4482838, 4482840, 4482841, ...             None

# %%
# Get single course
course_id = 1000964
tk.courses.get(course_id)
# Out:
# {'id': 1000964,
#  'name': 'Python : Pour approfondir',
#  'slug': 'python-pour-approfondir',
#  'subtitle': None,
#  'product_id': 1051673,
#  'description': None,
#  'intro_video_youtube': None,
#  'contact_information': None,
#  'keywords': None,
#  'duration': None,
#  'banner_image_url': '/assets/tenant/default-course-banner.jpg',
#  'course_card_image_url': 'https://thinkific-import.s3.amazonaws.com/370184/dhIXVLSxR626eefAOIiy_pexels-jan-kop%C5%99iva-3280908.jpg',
#  'intro_video_wistia_identifier': None,
#  'administrator_user_ids': [],
#  'user_id': 30297688,
#  'reviews_enabled': False,
#  'instructor_id': 429558,
#  'chapter_ids': [4563930,
#   4482837,
#   4482838,
#   4482840,
#   4482841,
#   4482844,
#   4482847],
#  'course_card_text': None}
